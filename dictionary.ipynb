# %%
# Empty dictionary
empty_dict = {}
also_empty = dict()

# Dictionary with data
student = {
    "name": "Alice",
    "age": 20,
    "grade": "A",
    "subjects": ["Math", "Physics", "Chemistry"]
}

# Keys can be strings, numbers, or tuples
mixed_keys = {
    "name": "Bob",
    1: "first",
    (0, 0): "origin"
}
print(student)
age=student.pop("age")
# Out:
# {'name': 'Alice', 'age': 20, 'grade': 'A', 'subjects': ['Math', 'Physics', 'Chemistry']}

# %%
student = {"name": "Alice", "age": 20, "grade": "A"}

# Remove specific key
del student["grade"]

# Remove and return value
age = student.pop("age")  # Returns 20, removes "age" from dict

# Remove last item (Python 3.7+)
last_item = student.popitem()

# Clear all items
#student.clear()  # {}
print(student)
# Out:
# {}

# %%
Book= {
    "title": "The Great Gatsby",
    "author": "F. Scott Fitzgerald",
    "year": 1925,
    "pages": 180
}
#
print(Book["author"])
Book["Genre"]="Fiction"
Book["year"]=2023
print(Book)
# Out:
# F. Scott Fitzgerald
# {'title': 'The Great Gatsby', 'author': 'F. Scott Fitzgerald', 'year': 2023, 'pages': 180, 'Genre': 'Fiction'}

# %%
prices = {"apple": 0.50, "banana": 0.30, "orange": 0.60, "grape": 2.00}

# Print each fruit and its price in the format: "apple costs $0.50"
#Find and print the most expensive fruit

prices = {"apple": 0.50, "banana": 0.30, "orange": 0.60, "grape": 2.00}

for i in prices.items():
    print(i[0],"cost$",i[1])
imax=

print(imax)
# Out:
# apple cost$ 0.5
# banana cost$ 0.3
# orange cost$ 0.6
# grape cost$ 2.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 12
#       8 for i in prices.items():
#       9     print(i[0],"cost$",i[1])
# ---> 12 print(imax)
#
# NameError: name 'imax' is not defined

# %%
n=int(input("enter any no:"))
if n%2 !=0:
    print("wired")
elif 2<=n<=5:
    print("Not wired")
elif 6<=n<=20:
    print("wired")
elif n>20 and n%2==0:
    print("Not wired")
# Out:
# Not wired
