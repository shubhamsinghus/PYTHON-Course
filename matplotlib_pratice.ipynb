# %%
# Basic Level
#
# What is Matplotlib and what is it used for?
# How do you import Matplotlib in Python? What is the conventional alias used?
# What is the difference between pyplot.plot() and pyplot.scatter()?
# How do you add a title, x-label, and y-label to a plot?
# What is the purpose of pyplot.show() function?
# How do you create a simple line plot with Matplotlib?
# What are the different line styles available in Matplotlib?
# How do you change the color of a plot line?
#
# Intermediate Level
#
# What is the difference between plt.figure() and plt.subplot()?
# How do you create multiple subplots in a single figure?
# Explain the difference between the stateful (pyplot) and object-oriented interface in Matplotlib.
# How do you save a figure to a file? What formats are supported?
# What is the purpose of plt.legend() and how do you customize it?
# How do you create a bar chart and a histogram in Matplotlib?
# What are the different marker styles available for scatter plots?
# How do you adjust the figure size and DPI (resolution)?
# What is the purpose of plt.grid() and how do you customize it?
#
# Advanced Level
#
# How do you create a plot with two different y-axes (using twinx())?
# What are style sheets in Matplotlib and how do you use them?
# How do you create custom colormaps for visualizations?
# Explain the difference between plt.tight_layout() and plt.subplots_adjust().
# How do you add annotations and arrows to specific points on a plot?
# What is the use of Artist objects in Matplotlib?
# How do you create animated plots using Matplotlib?
# How do you customize tick labels and positions on axes?
# What is the difference between imshow() and matshow() for displaying images?
# How do you create 3D plots using Matplotlib's mplot3d toolkit?
#
# Practical/Coding Questions
#
# Write code to plot a sine and cosine wave on the same graph with different colors and a legend.
# Create a 2x2 grid of subplots showing different types of plots (line, scatter, bar, histogram).
# How would you visualize a correlation matrix as a heatmap?

# %%
Matplotlib is the python libary used for creation pyplot,graph, bargraph,histogram chart ,and Pie chart for better repreastation of data.

# %%
pip install matplotlib
import matplotlib.pyplot as plt

# %%
# pyplot.plot is draw graph  on specific point and whereas pyplot.scatter is point scater in graph

# %%
pyplot.title(fcc),pyplot.xlabel(fisc),pyplot.ylabel(jij)

# %%
The function  of pyplot.show is to show the representation of data on graph/chart or to show the plots.
plt.show() displays the figure window. It's necessary in scripts to render and show the plot. In interactive environments like Jupyter notebooks, it may not be required.
# Out:
#   Cell In[3], line 1
#     The function  of pyplot.show is to show the representation of data on graph/chart
#         ^
# SyntaxError: invalid syntax
