# %%
import pandas as pd

# %%
#series DS 1D# labeled Array
s=pd.Series([20,40,60])
print(s)
# Out:
# 0    20
# 1    40
# 2    60
# dtype: int64

# %%
s=pd.Series([20,40,50],index=(1,2,3))
print(s)
# Out:
# 1    20
# 2    40
# 3    50
# dtype: int64

# %%
s=pd.Series([10,20,30,40,60],index=('a','b','c','d','e'))
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    60
# dtype: int64

# %%
# 1d=series operations 

#pandas

#2d labeled data structure(rows & columns)

df=pd.DataFrame({'arr':["sumit" ,"shubham","shivam","sahil"],'age' :[ 21,33,25,12]},index=('1','2','3','4'))
print(df)
print(df)
# Out:
#        arr  age
# 1    sumit   21
# 2  shubham   33
# 3   shivam   25
# 4    sahil   12
#        arr  age
# 1    sumit   21
# 2  shubham   33
# 3   shivam   25
# 4    sahil   12

# %%
#dictonary, lists, list of dict, numpy array
#from dictonary
df=pd.DataFrame({'x':[1,2,3],'y':[4,5,6]},index=('a','b','c'))
print(df)
# Out:
#    x  y
# a  1  4
# b  2  5
# c  3  6

# %%
#from list
df=pd.DataFrame(([1,2],[3,4]))
print(df)
print(df[0])
print(df[1])
# Out:
#    0  1
# 0  1  2
# 1  3  4
# 0    1
# 1    3
# Name: 0, dtype: int64
# 0    2
# 1    4
# Name: 1, dtype: int64

# %%
df=pd.DataFrame(([{'A':1,'B':2},{'A':3,'B':4}]))
print(df)
# Out:
#    A  B
# 0  1  2
# 1  3  4

# %%
# from numpy array
import numpy as np 
df = pd.DataFrame(np.arange(9).reshape(3,3), columns = ['A', 'B', 'c'])
print(df)
# Out:
#    A  B  c
# 0  0  1  2
# 1  3  4  5
# 2  6  7  8

# %%
# csv
# Excel
# Json
#SQL
#HTML

# %%
# read_csv
# to_csv
df = pd.read_csv('C:\\Users\\sri44\\Desktop\\Pandas\\House_Rent_Dataset.csv')
df
# Out:
#       Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     5/18/2022    2  10000  1100  Ground out of 2   Super Area
# 1     5/13/2022    2  20000   800       1 out of 3   Super Area
# 2     5/16/2022    2  17000  1000       1 out of 3   Super Area
# 3      7/4/2022    2  10000   800       1 out of 2   Super Area
# 4      5/9/2022    2   7500   850       1 out of 2  Carpet Area
# ...         ...  ...    ...   ...              ...          ...
# 4741  5/18/2022    2  15000  1000       3 out of 5  Carpet Area
# 4742  5/15/2022    3  29000  2000       1 out of 4   Super Area
# 4743  7/10/2022    3  35000  1750       3 out of 5  Carpet Area
# 4744   7/6/2022    3  45000  1500     23 out of 34  Carpet Area
# 4745   5/4/2022    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
df=pd.read_csv(r"C:\Users\sri44\Desktop\SH\file.csv")
df.appply(function)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27928\1844294334.py in ?()
#       1 df=pd.read_csv(r"C:\Users\sri44\Desktop\SH\file.csv")
# ----> 2 df.appply(function)
#
# c:\Users\sri44\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'appply'

# %%
df

# %%
df.iloc[1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df.iloc[1]
#
# AttributeError: 'str' object has no attribute 'iloc'

# %%
df.loc[4444,"City"]
# Out:
# 'Hyderabad'

# %%
df.loc[2]
# Out:
# Posted On                          5/16/2022
# BHK                                        2
# Rent                                   17000
# Size                                    1000
# Floor                             1 out of 3
# Area Type                         Super Area
# Area Locality        Salt Lake City Sector 2
# City                                 Kolkata
# Furnishing Status             Semi-Furnished
# Tenant Preferred            Bachelors/Family
# Bathroom                                   1
# Point of Contact               Contact Owner
# Name: 2, dtype: object

# %%
df[df['Rent'] > 20000,[City]]      # Age greater than 28
# df[df['City'] == 'Delhi']
# Out:
#       Posted On  BHK   Rent  Size         Floor    Area Type  \
# 8      6/7/2022    2  26000   800    1 out of 2  Carpet Area
# 10    5/23/2022    3  25000  1200    1 out of 4  Carpet Area
# 15     6/1/2022    3  40000  1286    1 out of 1  Carpet Area
# 34    5/10/2022    3  22000  1100    2 out of 3  Carpet Area
# 38    6/10/2022    2  21000   900    1 out of 2  Carpet Area
# ...         ...  ...    ...   ...           ...          ...
# 4735   6/8/2022    3  35000  1250    4 out of 5   Super Area
# 4739   7/6/2022    2  25000  1040    2 out of 4  Carpet Area
# 4742  5/15/2022    3  29000  2000    1 out of 4   Super Area
# 4743  7/10/2022    3  35000  1750    3 out of 5  Carpet Area
# 4744   7/6/2022    3  45000  1500  23 out of 34  Carpet Area
#
#                         Area Locality       City Furnishing Status  \
# 8     Palm Avenue Kolkata, Ballygunge    Kolkata       Unfurnished
# 10    Action Area 1, Rajarhat Newtown    Kolkata    Semi-Furnished
# ...

# %%
df['Age+5'] = df['Age'] + 5
df.groupby('City')['Age'].mean()
pd.merge(df1, df2, on='Name')
df.dropna()             # Remove missing rows
df.fillna(0)            # Replace missing with 0
📥 Data Input/Output
pd.read_csv() → Read CSV file into DataFrame

pd.read_excel() → Read Excel file

pd.read_sql() → Read from SQL database

df.to_csv() → Save DataFrame to CSV

df.to_excel() → Save DataFrame to Excel

🔍 Data Exploration
df.head() → First 5 rows

df.tail() → Last 5 rows

df.info() → Column types + non-null counts

df.describe() → Summary statistics (mean, std, min, max)

df.shape → Dimensions (rows, columns)

df.columns → Column names

🎯 Selection & Indexing
df['col'] → Select single column

df[['col1','col2']] → Select multiple columns

df.iloc[0] → Select row by index position

df.loc[2,'col'] → Select row by label + column

df.at[2,'col'] → Fast access for single value

🔎 Filtering
df[df['Age'] > 30] → Filter rows by condition

df.query("Age > 30 & City == 'Delhi'") → SQL-like queries

🛠️ Data Cleaning
df.dropna() → Remove missing values

df.fillna(0) → Replace missing values

df.drop_duplicates() → Remove duplicate rows

df.rename(columns={'old':'new'}) → Rename columns

df.astype(float) → Change data type

➕ Column Operations
df['new'] = df['Age'] + 5 → Create new column

df.apply(func) → Apply function to rows/columns

df.map(func) → Apply function to Series

📊 Grouping & Aggregation
df.groupby('City')['Age'].mean() → Group by City, average Age

df.agg({'Age':'mean','Salary':'sum'}) → Multiple aggregations

df.pivot_table(values='Age', index='City', aggfunc='mean') → Pivot tables

🔗 Merging & Joining
pd.concat([df1, df2]) → Stack DataFrames

pd.merge(df1, df2, on='id') → SQL-style join

📈 Sorting
df.sort_values('Age') → Sort by column

df.sort_index() → Sort by index

🔄 Reshaping
df.melt() → Unpivot DataFrame

df.pivot() → Pivot DataFrame

df.stack() / df.unstack() → Reshape hierarchical indexes

🧮 Statistics
df.mean() → Column means

df.median() → Column medians

df.std() → Standard deviation

df.value_counts() → Frequency counts

🕒 Time Series
pd.to_datetime(df['date']) → Convert to datetime

df.resample('M').mean() → Resample by month
df.to_string() -> to print entire data frame
# Out:
#   Cell In[101], line 6
#     📥 Data Input/Output
#     ^
# SyntaxError: invalid character '📥' (U+1F4E5)

# %%
pd.concat(["City","Area Locality"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[153], line 1
# ----> 1 pd.concat(["City","Area Locality"])
#
# File c:\Users\sri44\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# ...

# %%
print(df[])
# Out:
#       Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     5/18/2022    2  10000  1100  Ground out of 2   Super Area
# 1     5/13/2022    2  20000   800       1 out of 3   Super Area
# 2     5/16/2022    2  17000  1000       1 out of 3   Super Area
# 3      7/4/2022    2  10000   800       1 out of 2   Super Area
# 4      5/9/2022    2   7500   850       1 out of 2  Carpet Area
# ...         ...  ...    ...   ...              ...          ...
# 4741  5/18/2022    2  15000  1000       3 out of 5  Carpet Area
# 4742  5/15/2022    3  29000  2000       1 out of 4   Super Area
# 4743  7/10/2022    3  35000  1750       3 out of 5  Carpet Area
# 4744   7/6/2022    3  45000  1500     23 out of 34  Carpet Area
# 4745   5/4/2022    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
df.pivot(1,"city",) 
+
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 df.pivot(1,"city")
#
# TypeError: DataFrame.pivot() takes 1 positional argument but 3 were given

# %%
print("hello world")
# Out:
# hello world

# %%
prices = {"apple": 0.50, "banana": 0.30, "orange": 0.60, "grape": 2.00}

# Print each fruit and its price in the format: "apple costs $0.50"


for i in prices.items():
    print(i[0],"cost$",i[1])
# Out:
# apple cost$ apple
# banana cost$ banana
# orange cost$ orange
# grape cost$ grape
